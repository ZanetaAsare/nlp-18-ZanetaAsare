# %%
amazon = open("amazon_cells_labelled.txt","r")
yelp = open("yelp_labelled.txt","r")
imdb = open("imdb_labelled.txt","r")

# %%
classes = {}          #dictionary containing the various sentences separated into positive and negative classes
classes['0'] = []
classes['1'] = []

# %%
for i in range(500):
    yelp_read = yelp.readlines(1)              #reading all three lines
    am_read = amazon.readlines(1)
    im_read = imdb.readlines(1)

    str1 = yelp_read[0]                         #extracting the string out of the list object type above
    str2 = am_read[0]
    str3 = im_read[0]
    
    
    yelp_split = str1.split()                   #splitting the string to get the number at the end of the sentence
    am_split = str2.split()
    im_split = str3.split()

    
    
    if yelp_split.pop() == '0':                 #checking if number is 0 or 1
        list0 = classes['0']                    #the value for classes['0'] is assigned to list0
        list0.append(str1)                      #sentence is appended to list0 
        classes['0'] = list0                    #value for classes['0'] is updated with appended list
    else:
        list1 = classes['1']
        list1.append(str1)
        classes['1'] = list1
    
    
    if am_split.pop() == '0':
        list0 = classes['0']
        list0.append(str2)
        classes['0'] = list0
    else:
        list1 = classes['1']
        list1.append(str2)
        classes['1'] = list1
    
    
    if im_split.pop() == '0':
        list0 = classes['0']
        list0.append(str3)
        classes['0'] = list0
    else:
        list1 = classes['1']
        list1.append(str3)
        classes['1'] = list1    


list0_len = len(list0)    
list1_len = len(list1)
totalnum = list0_len + list1_len

print('Negative Class\n')
print('Number is: %d\n' % list0_len)
print(classes['0'])                   #contains the read lines of all the negative sentences
print('\n')
print('Positive Class\n')
print('Number is: %d\n' % list1_len)
print(classes['1'])                   #contains the read lines of all the positive sentences
# Out:
# Negative Class
#
# Number is: 727
#
# ['So there is no way for me to plug it in here in the US unless I go by a converter.\t0\n', 'A very, very, very slow-moving, aimless movie about a distressed, drifting young man.  \t0\n', 'Crust is not good.\t0\n', 'Not sure who was more lost - the flat characters or the audience, nearly half of whom walked out.  \t0\n', 'Not tasty and the texture was just nasty.\t0\n', 'Attempting artiness with black & white and clever camera angles, the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.  \t0\n', 'Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!\t0\n', 'Very little music or anything to speak of.  \t0\n', 'Now I am getting angry and I want my damn pho.\t0\n', 'I have to jiggle the plug to get it to line up right to get decent volume.\t0\n', "The rest of the movie lacks art, charm, meaning... If it's about emptiness, it works I guess because it's empty.  \t0\n", "Honeslty it didn't taste THAT fresh.)\t0\n", 'If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.\t0\n', 'Wasted two hours.  \t0\n', 'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\t0\n', 'Needless to say, I wasted my money.\t0\n', 'A bit predictable.  \t0\n', 'What a waste of money and time!.\t0\n', 'Would not go back.\t0\n', 'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.\t0\n', 'If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.\t0\n', 'I was disgusted because I was pretty sure that was human hair.\t0\n', 'The design is very odd, as the ear "clip" is not very comfortable at all.\t0\n', 'I was shocked because no signs indicate cash only.\t0\n', 'It had some average acting from the main person, and it was a low budget as you clearly can see.  \t0\n', 'I advise EVERYONE DO NOT BE FOOLED!\t0\n', 'Waitress was a little slow in service.\t0\n', 'This place is not worth your time, let alone Vegas.\t0\n', 'did not like at all.\t0\n', 'It clicks into place in a way that makes you wonder how long that mechanism would last.\t0\n', 'The Burrittos Blah!\t0\n', "I went on Motorola's website and followed all directions, but could not get it to pair again.\t0\n", 'The commercials are the most misleading.\t0\n', 'I bought it for my mother and she had a problem with the battery.\t0\n', 'This short film certainly pulls no punches.  \t0\n', '- They never brought a salad we asked for.\t0\n', 'Graphics is far from the best part of the game.  \t0\n', "I didn't think that the instructions provided were helpful to me.\t0\n", 'Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.\t0\n', 'People couldnt hear me talk and I had to pull out the earphone and talk on the phone.\t0\n', 'The worst was the salmon sashimi.\t0\n', "Doesn't hold charge.\t0\n", 'This is a simple little phone to use, but the breakage is unacceptible.\t0\n', 'This was like the final blow!\t0\n', 'It is unusable in a moving car at freeway speed.\t0\n', 'seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.\t0\n', 'I have two more years left in this contract and I hate this phone.\t0\n', 'Today the graphics are crap.  \t0\n', 'You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.\t0\n', 'Poor service, the waiter made me feel like I was stupid every time he came to the table.\t0\n', 'Poor Talk Time Performance.\t0\n', 'Service sucks.\t0\n', 'worthless product.\t0\n', 'This was a flick doomed from its conception.  \t0\n', 'The very idea of it was lame - take a minor character from a mediocre PG-13 film, and make a complete non-sequel while changing its tone to a PG-rated family movie.   ...
#
#
# Positive Class
#
# Number is: 773
#
# ['Wow... Loved this place.\t1\n', 'Good case, Excellent value.\t1\n', 'Great for the jawbone.\t1\n', 'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\t1\n', 'The selection on the menu was great and so were the prices.\t1\n', 'The mic is great.\t1\n', 'The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.  \t1\n', 'If you are Razr owner...you must have this!\t1\n', 'Saw the movie today and thought it was a good effort, good messages for kids.  \t1\n', 'The fries were great too.\t1\n', 'A great touch.\t1\n', 'Loved the casting of Jimmy Buffet as the science teacher.  \t1\n', 'Service was very prompt.\t1\n', 'And the sound quality is great.\t1\n', 'And those baby owls were adorable.  \t1\n', 'He was very impressed when going from the original battery to the extended battery.\t1\n', "The movie showed a lot of Florida at it's best, made it look very appealing.  \t1\n", 'The Songs Were The Best And The Muppets Were So Hilarious.  \t1\n', 'I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!\t1\n', 'Very good quality though\t1\n', 'It Was So Cool.  \t1\n', 'This is a very "right on case" movie that delivers everything almost right in your face.  \t1\n', 'Highly recommend for any one who has a blue tooth phone.\t1\n', 'Highly recommended.\t1\n', 'This review is long overdue, since I consider A Tale of Two Sisters to be the single greatest film ever made.  \t1\n', 'So Far So Good!.\t1\n', "I'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.  \t1\n", 'Works great!.\t1\n', 'It\'s practically perfect in all of them \x96 a true masterpiece in a sea of faux "masterpieces.  \t1\n', '" The structure of this film is easily the most tightly constructed in the history of cinema.  \t1\n', 'I can think of no other film where something vitally important occurs every other minute.  \t1\n', 'The food, amazing.\t1\n', 'I bought this to use with my Kindle Fire and absolutely loved it!\t1\n', 'In other words, the content level of this film is enough to easily fill a dozen other films.  \t1\n', 'Service is also cute.\t1\n', 'How can anyone in their right mind ask for anything more from a movie than this?  \t1\n', 'I could care less... The interior is just beautiful.\t1\n', "I have yet to run this new battery below two bars and that's three days without charging.\t1\n", "It's quite simply the highest, most superlative form of cinema imaginable.  \t1\n", 'So they performed.\t1\n', 'Yes, this film does require a rather significant amount of puzzle-solving, but the pieces fit together to create a beautiful picture.  \t1\n', "That's right....the red velvet cake.....ohhh this stuff is so good.\t1\n", 'Great Pocket PC / phone combination.\t1\n', "I've owned this phone for 7 months now and can say that it's the best mobile phone I've had.\t1\n", 'This hole in the wall has great Mexican street tacos, and friendly staff.\t1\n', 'This is the number one best TH game in the series.  \t1\n', 'It deserves strong love.  \t1\n', 'It is an insane game.  \t1\n', 'Also there are combos like a burger, fries, and beer for 23 which is a decent deal.\t1\n', "There are massive levels, massive unlockable characters... it's just a massive game.  \t1\n", 'This product is ideal for people like me whose ears are very sensitive.\t1\n', 'Waste your money on this game.  \t1\n', 'I found this place by accident and I could not be happier.\t1\n', 'This is the kind of money that is wasted properly.  \t1\n', 'Actually, the graphics were good at the time.  \t1\n', 'Overall, I like this place a lot.\t1\n', 'Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended\t1\n', 'The only redeeming quality of the restaurant was that it was very inexpensive.\t1\n', 'As they say in Canada, This is the fun game, aye.  \t1\n', 'Ample portions and good pri ...

# %%
bag_words = {}       #dictionary containing bag of words separated into positive and negative classes
bag_words['0'] = []
bag_words['1'] = []

# %%
i = 0
word_list0 = []                    #initializing lists for containing the bag of words
word_list1 = []

for i in range(list0_len):          #an iteration through the negative list of words assigned to classes['0'] earlier
    sen0 = list0[i]              
    
    sen_split0 = sen0.split()       #extracted string sentences are split by space variable
    
    
    for j in range(len(sen_split0) - 1):        #an iteration through the extracted split string sentences
        word0 = sen_split0[j]
        word_list0.append(word0)              #words are appended into the word list initialized earlier
       
        
        #same process is applied to the positive class
for i in range(list1_len):               
    sen1 = list1[i]              

    sen_split1 = sen1.split()            
    
    for k in range(len(sen_split1) - 1):       
        word1 = sen_split1[k]
        word_list1.append(word1)        

        
bag_words['0'] = word_list0           #word lists are assigned to the bag_words dictionary according to their class
bag_words['1'] = word_list1
print('Negative Bag of Words\n')
print(bag_words['0'])
print('\n')
print('Positive Bag of Words\n')
print(bag_words['1'])
# Out:
# Negative Bag of Words
#
# ['So', 'there', 'is', 'no', 'way', 'for', 'me', 'to', 'plug', 'it', 'in', 'here', 'in', 'the', 'US', 'unless', 'I', 'go', 'by', 'a', 'converter.', 'A', 'very,', 'very,', 'very', 'slow-moving,', 'aimless', 'movie', 'about', 'a', 'distressed,', 'drifting', 'young', 'man.', 'Crust', 'is', 'not', 'good.', 'Not', 'sure', 'who', 'was', 'more', 'lost', '-', 'the', 'flat', 'characters', 'or', 'the', 'audience,', 'nearly', 'half', 'of', 'whom', 'walked', 'out.', 'Not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty.', 'Attempting', 'artiness', 'with', 'black', '&', 'white', 'and', 'clever', 'camera', 'angles,', 'the', 'movie', 'disappointed', '-', 'became', 'even', 'more', 'ridiculous', '-', 'as', 'the', 'acting', 'was', 'poor', 'and', 'the', 'plot', 'and', 'lines', 'almost', 'non-existent.', 'Tied', 'to', 'charger', 'for', 'conversations', 'lasting', 'more', 'than', '45', 'minutes.MAJOR', 'PROBLEMS!!', 'Very', 'little', 'music', 'or', 'anything', 'to', 'speak', 'of.', 'Now', 'I', 'am', 'getting', 'angry', 'and', 'I', 'want', 'my', 'damn', 'pho.', 'I', 'have', 'to', 'jiggle', 'the', 'plug', 'to', 'get', 'it', 'to', 'line', 'up', 'right', 'to', 'get', 'decent', 'volume.', 'The', 'rest', 'of', 'the', 'movie', 'lacks', 'art,', 'charm,', 'meaning...', 'If', "it's", 'about', 'emptiness,', 'it', 'works', 'I', 'guess', 'because', "it's", 'empty.', 'Honeslty', 'it', "didn't", 'taste', 'THAT', 'fresh.)', 'If', 'you', 'have', 'several', 'dozen', 'or', 'several', 'hundred', 'contacts,', 'then', 'imagine', 'the', 'fun', 'of', 'sending', 'each', 'of', 'them', 'one', 'by', 'one.', 'Wasted', 'two', 'hours.', 'The', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer.', 'Needless', 'to', 'say,', 'I', 'wasted', 'my', 'money.', 'A', 'bit', 'predictable.', 'What', 'a', 'waste', 'of', 'money', 'and', 'time!.', 'Would', 'not', 'go', 'back.', 'The', 'cashier', 'had', 'no', 'care', 'what', 'so', 'ever', 'on', 'what', 'I', 'had', 'to', 'say', 'it', 'still', 'ended', 'up', 'being', 'wayyy', 'overpriced.', 'If', 'the', 'two', 'were', 'seperated', 'by', 'a', 'mere', '5+', 'ft', 'I', 'started', 'to', 'notice', 'excessive', 'static', 'and', 'garbled', 'sound', 'from', 'the', 'headset.', 'I', 'was', 'disgusted', 'because', 'I', 'was', 'pretty', 'sure', 'that', 'was', 'human', 'hair.', 'The', 'design', 'is', 'very', 'odd,', 'as', 'the', 'ear', '"clip"', 'is', 'not', 'very', 'comfortable', 'at', 'all.', 'I', 'was', 'shocked', 'because', 'no', 'signs', 'indicate', 'cash', 'only.', 'It', 'had', 'some', 'average', 'acting', 'from', 'the', 'main', 'person,', 'and', 'it', 'was', 'a', 'low', 'budget', 'as', 'you', 'clearly', 'can', 'see.', 'I', 'advise', 'EVERYONE', 'DO', 'NOT', 'BE', 'FOOLED!', 'Waitress', 'was', 'a', 'little', 'slow', 'in', 'service.', 'This', 'place', 'is', 'not', 'worth', 'your', 'time,', 'let', 'alone', 'Vegas.', 'did', 'not', 'like', 'at', 'all.', 'It', 'clicks', 'into', 'place', 'in', 'a', 'way', 'that', 'makes', 'you', 'wonder', 'how', 'long', 'that', 'mechanism', 'would', 'last.', 'The', 'Burrittos', 'Blah!', 'I', 'went', 'on', "Motorola's", 'website', 'and', 'followed', 'all', 'directions,', 'but', 'could', 'not', 'get', 'it', 'to', 'pair', 'again.', 'The', 'commercials', 'are', 'the', 'most', 'misleading.', 'I', 'bought', 'it', 'for', 'my', 'mother', 'and', 'she', 'had', 'a', 'problem', 'with', 'the', 'battery.', 'This', 'short', 'film', 'certainly', 'pulls', 'no', 'punches.', '-', 'They', 'never', 'brought', 'a', 'salad', 'we', 'asked', 'for.', 'Graphics', 'is', 'far', 'from', 'the', 'best', 'part', 'of', 'the', 'game.', 'I', "didn't", 'think', 'that', 'the', 'instructions', 'provided', 'were', 'helpful', 'to', 'me.', 'Took', 'an', 'hour', 'to', 'get', 'our', 'food', 'only', '4', 'tables', 'in', 'restaurant', 'my', 'food', 'was', 'Luke', 'warm,', 'Our', 'sever', 'was', 'running', 'around', 'like', 'he', 'was', 'totally',  ...
#
#
# Positive Bag of Words
#
# ['Wow...', 'Loved', 'this', 'place.', 'Good', 'case,', 'Excellent', 'value.', 'Great', 'for', 'the', 'jawbone.', 'Stopped', 'by', 'during', 'the', 'late', 'May', 'bank', 'holiday', 'off', 'Rick', 'Steve', 'recommendation', 'and', 'loved', 'it.', 'The', 'selection', 'on', 'the', 'menu', 'was', 'great', 'and', 'so', 'were', 'the', 'prices.', 'The', 'mic', 'is', 'great.', 'The', 'best', 'scene', 'in', 'the', 'movie', 'was', 'when', 'Gerardo', 'is', 'trying', 'to', 'find', 'a', 'song', 'that', 'keeps', 'running', 'through', 'his', 'head.', 'If', 'you', 'are', 'Razr', 'owner...you', 'must', 'have', 'this!', 'Saw', 'the', 'movie', 'today', 'and', 'thought', 'it', 'was', 'a', 'good', 'effort,', 'good', 'messages', 'for', 'kids.', 'The', 'fries', 'were', 'great', 'too.', 'A', 'great', 'touch.', 'Loved', 'the', 'casting', 'of', 'Jimmy', 'Buffet', 'as', 'the', 'science', 'teacher.', 'Service', 'was', 'very', 'prompt.', 'And', 'the', 'sound', 'quality', 'is', 'great.', 'And', 'those', 'baby', 'owls', 'were', 'adorable.', 'He', 'was', 'very', 'impressed', 'when', 'going', 'from', 'the', 'original', 'battery', 'to', 'the', 'extended', 'battery.', 'The', 'movie', 'showed', 'a', 'lot', 'of', 'Florida', 'at', "it's", 'best,', 'made', 'it', 'look', 'very', 'appealing.', 'The', 'Songs', 'Were', 'The', 'Best', 'And', 'The', 'Muppets', 'Were', 'So', 'Hilarious.', 'I', 'tried', 'the', 'Cape', 'Cod', 'ravoli,', 'chicken,with', 'cranberry...mmmm!', 'Very', 'good', 'quality', 'though', 'It', 'Was', 'So', 'Cool.', 'This', 'is', 'a', 'very', '"right', 'on', 'case"', 'movie', 'that', 'delivers', 'everything', 'almost', 'right', 'in', 'your', 'face.', 'Highly', 'recommend', 'for', 'any', 'one', 'who', 'has', 'a', 'blue', 'tooth', 'phone.', 'Highly', 'recommended.', 'This', 'review', 'is', 'long', 'overdue,', 'since', 'I', 'consider', 'A', 'Tale', 'of', 'Two', 'Sisters', 'to', 'be', 'the', 'single', 'greatest', 'film', 'ever', 'made.', 'So', 'Far', 'So', 'Good!.', "I'll", 'put', 'this', 'gem', 'up', 'against', 'any', 'movie', 'in', 'terms', 'of', 'screenplay,', 'cinematography,', 'acting,', 'post-production,', 'editing,', 'directing,', 'or', 'any', 'other', 'aspect', 'of', 'film-making.', 'Works', 'great!.', "It's", 'practically', 'perfect', 'in', 'all', 'of', 'them', '\x96', 'a', 'true', 'masterpiece', 'in', 'a', 'sea', 'of', 'faux', '"masterpieces.', '"', 'The', 'structure', 'of', 'this', 'film', 'is', 'easily', 'the', 'most', 'tightly', 'constructed', 'in', 'the', 'history', 'of', 'cinema.', 'I', 'can', 'think', 'of', 'no', 'other', 'film', 'where', 'something', 'vitally', 'important', 'occurs', 'every', 'other', 'minute.', 'The', 'food,', 'amazing.', 'I', 'bought', 'this', 'to', 'use', 'with', 'my', 'Kindle', 'Fire', 'and', 'absolutely', 'loved', 'it!', 'In', 'other', 'words,', 'the', 'content', 'level', 'of', 'this', 'film', 'is', 'enough', 'to', 'easily', 'fill', 'a', 'dozen', 'other', 'films.', 'Service', 'is', 'also', 'cute.', 'How', 'can', 'anyone', 'in', 'their', 'right', 'mind', 'ask', 'for', 'anything', 'more', 'from', 'a', 'movie', 'than', 'this?', 'I', 'could', 'care', 'less...', 'The', 'interior', 'is', 'just', 'beautiful.', 'I', 'have', 'yet', 'to', 'run', 'this', 'new', 'battery', 'below', 'two', 'bars', 'and', "that's", 'three', 'days', 'without', 'charging.', "It's", 'quite', 'simply', 'the', 'highest,', 'most', 'superlative', 'form', 'of', 'cinema', 'imaginable.', 'So', 'they', 'performed.', 'Yes,', 'this', 'film', 'does', 'require', 'a', 'rather', 'significant', 'amount', 'of', 'puzzle-solving,', 'but', 'the', 'pieces', 'fit', 'together', 'to', 'create', 'a', 'beautiful', 'picture.', "That's", 'right....the', 'red', 'velvet', 'cake.....ohhh', 'this', 'stuff', 'is', 'so', 'good.', 'Great', 'Pocket', 'PC', '/', 'phone', 'combination.', "I've", 'owned', 'this', 'phone', 'for', '7', 'months', 'now', 'and', 'can', 'say', 'that', "it's", 'the', 'best', 'mobile', 'phone', "I've", 'had.', 'This', 'hole', 'in', 'the', 'wall', 'has', 'great', ' ...

# %%
#calculating probabilities of positive and negative sentences in the document
import math             

logprior = {}
logprior['0'] = math.log(list0_len/totalnum)
logprior['1'] = math.log(list1_len/totalnum)

print(logprior['0'])
print(logprior['1'])
# Out:
# -0.724293909556782
# -0.6629413385028795

# %%
V = word_list0 + word_list1 
print(V)

lenV = len(V)
# Out:
# ['So', 'there', 'is', 'no', 'way', 'for', 'me', 'to', 'plug', 'it', 'in', 'here', 'in', 'the', 'US', 'unless', 'I', 'go', 'by', 'a', 'converter.', 'A', 'very,', 'very,', 'very', 'slow-moving,', 'aimless', 'movie', 'about', 'a', 'distressed,', 'drifting', 'young', 'man.', 'Crust', 'is', 'not', 'good.', 'Not', 'sure', 'who', 'was', 'more', 'lost', '-', 'the', 'flat', 'characters', 'or', 'the', 'audience,', 'nearly', 'half', 'of', 'whom', 'walked', 'out.', 'Not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty.', 'Attempting', 'artiness', 'with', 'black', '&', 'white', 'and', 'clever', 'camera', 'angles,', 'the', 'movie', 'disappointed', '-', 'became', 'even', 'more', 'ridiculous', '-', 'as', 'the', 'acting', 'was', 'poor', 'and', 'the', 'plot', 'and', 'lines', 'almost', 'non-existent.', 'Tied', 'to', 'charger', 'for', 'conversations', 'lasting', 'more', 'than', '45', 'minutes.MAJOR', 'PROBLEMS!!', 'Very', 'little', 'music', 'or', 'anything', 'to', 'speak', 'of.', 'Now', 'I', 'am', 'getting', 'angry', 'and', 'I', 'want', 'my', 'damn', 'pho.', 'I', 'have', 'to', 'jiggle', 'the', 'plug', 'to', 'get', 'it', 'to', 'line', 'up', 'right', 'to', 'get', 'decent', 'volume.', 'The', 'rest', 'of', 'the', 'movie', 'lacks', 'art,', 'charm,', 'meaning...', 'If', "it's", 'about', 'emptiness,', 'it', 'works', 'I', 'guess', 'because', "it's", 'empty.', 'Honeslty', 'it', "didn't", 'taste', 'THAT', 'fresh.)', 'If', 'you', 'have', 'several', 'dozen', 'or', 'several', 'hundred', 'contacts,', 'then', 'imagine', 'the', 'fun', 'of', 'sending', 'each', 'of', 'them', 'one', 'by', 'one.', 'Wasted', 'two', 'hours.', 'The', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer.', 'Needless', 'to', 'say,', 'I', 'wasted', 'my', 'money.', 'A', 'bit', 'predictable.', 'What', 'a', 'waste', 'of', 'money', 'and', 'time!.', 'Would', 'not', 'go', 'back.', 'The', 'cashier', 'had', 'no', 'care', 'what', 'so', 'ever', 'on', 'what', 'I', 'had', 'to', 'say', 'it', 'still', 'ended', 'up', 'being', 'wayyy', 'overpriced.', 'If', 'the', 'two', 'were', 'seperated', 'by', 'a', 'mere', '5+', 'ft', 'I', 'started', 'to', 'notice', 'excessive', 'static', 'and', 'garbled', 'sound', 'from', 'the', 'headset.', 'I', 'was', 'disgusted', 'because', 'I', 'was', 'pretty', 'sure', 'that', 'was', 'human', 'hair.', 'The', 'design', 'is', 'very', 'odd,', 'as', 'the', 'ear', '"clip"', 'is', 'not', 'very', 'comfortable', 'at', 'all.', 'I', 'was', 'shocked', 'because', 'no', 'signs', 'indicate', 'cash', 'only.', 'It', 'had', 'some', 'average', 'acting', 'from', 'the', 'main', 'person,', 'and', 'it', 'was', 'a', 'low', 'budget', 'as', 'you', 'clearly', 'can', 'see.', 'I', 'advise', 'EVERYONE', 'DO', 'NOT', 'BE', 'FOOLED!', 'Waitress', 'was', 'a', 'little', 'slow', 'in', 'service.', 'This', 'place', 'is', 'not', 'worth', 'your', 'time,', 'let', 'alone', 'Vegas.', 'did', 'not', 'like', 'at', 'all.', 'It', 'clicks', 'into', 'place', 'in', 'a', 'way', 'that', 'makes', 'you', 'wonder', 'how', 'long', 'that', 'mechanism', 'would', 'last.', 'The', 'Burrittos', 'Blah!', 'I', 'went', 'on', "Motorola's", 'website', 'and', 'followed', 'all', 'directions,', 'but', 'could', 'not', 'get', 'it', 'to', 'pair', 'again.', 'The', 'commercials', 'are', 'the', 'most', 'misleading.', 'I', 'bought', 'it', 'for', 'my', 'mother', 'and', 'she', 'had', 'a', 'problem', 'with', 'the', 'battery.', 'This', 'short', 'film', 'certainly', 'pulls', 'no', 'punches.', '-', 'They', 'never', 'brought', 'a', 'salad', 'we', 'asked', 'for.', 'Graphics', 'is', 'far', 'from', 'the', 'best', 'part', 'of', 'the', 'game.', 'I', "didn't", 'think', 'that', 'the', 'instructions', 'provided', 'were', 'helpful', 'to', 'me.', 'Took', 'an', 'hour', 'to', 'get', 'our', 'food', 'only', '4', 'tables', 'in', 'restaurant', 'my', 'food', 'was', 'Luke', 'warm,', 'Our', 'sever', 'was', 'running', 'around', 'like', 'he', 'was', 'totally',  ...

# %%
#dictionaries for storing the number of times a word in the vocabulary appears in either the positive or negative class

count_word0 = {}     
count_word1 = {}

# %%
#counting the number of times a word in the vocabulary appears in either the positive or negative class

for w in range(lenV):         #an iteration through the vocabulary bag of words
    count = 0
    check = V[w]
    
    for k in range(len(word_list0)):      #for each word in the vocabulary, check the number of times it appears in the negative class and increment count
        if check == word_list0[k]:
            count = count + 1
   
    count_word0[check] = count          #the word and its count value is stored in a dictionary count_word0
    


for w in range(lenV):           #same process applies to the positive class
    count = 0
    check = V[w]
    
    for k in range(len(word_list1)):
        if check == word_list1[k]:
            count = count + 1
   
    count_word1[check] = count

    
print(count_word0)
print('\n')
print('\n')
print('\n')
print('\n')
print(count_word1)
# Out:
# {'So': 3, 'there': 17, 'is': 152, 'no': 25, 'way': 9, 'for': 89, 'me': 15, 'to': 165, 'plug': 5, 'it': 105, 'in': 86, 'here': 8, 'the': 348, 'US': 1, 'unless': 4, 'I': 230, 'go': 16, 'by': 20, 'a': 196, 'converter.': 1, 'A': 8, 'very,': 2, 'very': 40, 'slow-moving,': 1, 'aimless': 1, 'movie': 40, 'about': 20, 'distressed,': 1, 'drifting': 1, 'young': 1, 'man.': 1, 'Crust': 1, 'not': 90, 'good.': 7, 'Not': 16, 'sure': 6, 'who': 10, 'was': 162, 'more': 16, 'lost': 2, '-': 32, 'flat': 2, 'characters': 5, 'or': 21, 'audience,': 1, 'nearly': 1, 'half': 5, 'of': 154, 'whom': 1, 'walked': 2, 'out.': 4, 'tasty': 2, 'and': 221, 'texture': 1, 'just': 27, 'nasty.': 1, 'Attempting': 1, 'artiness': 1, 'with': 60, 'black': 3, '&': 9, 'white': 1, 'clever': 2, 'camera': 3, 'angles,': 1, 'disappointed': 8, 'became': 1, 'even': 22, 'ridiculous': 1, 'as': 41, 'acting': 15, 'poor': 9, 'plot': 10, 'lines': 3, 'almost': 4, 'non-existent.': 1, 'Tied': 1, 'charger': 2, 'conversations': 1, 'lasting': 2, 'than': 21, '45': 1, 'minutes.MAJOR': 1, 'PROBLEMS!!': 1, 'Very': 7, 'little': 12, 'music': 4, 'anything': 4, 'speak': 2, 'of.': 1, 'Now': 2, 'am': 9, 'getting': 5, 'angry': 1, 'want': 4, 'my': 54, 'damn': 2, 'pho.': 1, 'have': 43, 'jiggle': 1, 'get': 17, 'line': 4, 'up': 16, 'right': 5, 'decent': 1, 'volume.': 1, 'The': 121, 'rest': 4, 'lacks': 3, 'art,': 1, 'charm,': 1, 'meaning...': 1, 'If': 17, "it's": 8, 'emptiness,': 1, 'works': 1, 'guess': 5, 'because': 23, 'empty.': 1, 'Honeslty': 1, "didn't": 23, 'taste': 3, 'THAT': 3, 'fresh.)': 1, 'you': 40, 'several': 4, 'dozen': 1, 'hundred': 1, 'contacts,': 1, 'then': 10, 'imagine': 1, 'fun': 1, 'sending': 2, 'each': 2, 'them': 8, 'one': 26, 'one.': 2, 'Wasted': 1, 'two': 5, 'hours.': 2, 'potatoes': 1, 'were': 25, 'like': 34, 'rubber': 1, 'could': 18, 'tell': 4, 'they': 19, 'had': 35, 'been': 13, 'made': 13, 'ahead': 1, 'time': 17, 'being': 9, 'kept': 2, 'under': 1, 'warmer.': 1, 'Needless': 1, 'say,': 1, 'wasted': 4, 'money.': 5, 'bit': 5, 'predictable.': 1, 'What': 5, 'waste': 16, 'money': 7, 'time!.': 1, 'Would': 1, 'back.': 12, 'cashier': 1, 'care': 3, 'what': 10, 'so': 34, 'ever': 13, 'on': 57, 'say': 6, 'still': 11, 'ended': 1, 'wayyy': 1, 'overpriced.': 1, 'seperated': 1, 'mere': 1, '5+': 1, 'ft': 1, 'started': 3, 'notice': 1, 'excessive': 1, 'static': 1, 'garbled': 1, 'sound': 9, 'from': 19, 'headset.': 6, 'disgusted': 1, 'pretty': 7, 'that': 97, 'human': 2, 'hair.': 1, 'design': 3, 'odd,': 1, 'ear': 4, '"clip"': 1, 'comfortable': 2, 'at': 38, 'all.': 6, 'shocked': 1, 'signs': 1, 'indicate': 1, 'cash': 1, 'only.': 1, 'It': 32, 'some': 15, 'average': 4, 'main': 1, 'person,': 1, 'low': 4, 'budget': 1, 'clearly': 1, 'can': 16, 'see.': 1, 'advise': 1, 'EVERYONE': 1, 'DO': 2, 'NOT': 3, 'BE': 1, 'FOOLED!': 1, 'Waitress': 1, 'slow': 5, 'service.': 7, 'This': 37, 'place': 16, 'worth': 4, 'your': 21, 'time,': 3, 'let': 5, 'alone': 1, 'Vegas.': 3, 'did': 9, 'clicks': 1, 'into': 12, 'makes': 2, 'wonder': 1, 'how': 15, 'long': 5, 'mechanism': 1, 'would': 25, 'last.': 1, 'Burrittos': 1, 'Blah!': 1, 'went': 5, "Motorola's": 1, 'website': 1, 'followed': 1, 'all': 19, 'directions,': 1, 'but': 47, 'pair': 1, 'again.': 7, 'commercials': 1, 'are': 35, 'most': 6, 'misleading.': 1, 'bought': 5, 'mother': 1, 'she': 6, 'problem': 5, 'battery.': 2, 'short': 3, 'film': 12, 'certainly': 3, 'pulls': 1, 'punches.': 1, 'They': 6, 'never': 14, 'brought': 1, 'salad': 4, 'we': 15, 'asked': 2, 'for.': 1, 'Graphics': 1, 'far': 5, 'best': 2, 'part': 3, 'game.': 1, 'think': 13, 'instructions': 2, 'provided': 1, 'helpful': 2, 'me.': 4, 'Took': 1, 'an': 22, 'hour': 5, 'our': 10, 'food': 20, 'only': 29, '4': 3, 'tables': 2, 'restaurant': 3, 'Luke': 1, 'warm,': 1, 'Our': 1, 'sever': 1, 'running': 2, 'around': 4, 'he': 9, 'totally': 8, 'overwhelmed.': 1, 'People': 1, 'couldnt': 1, 'hear': 4, 'talk': 6, 'pull': 1, 'out': 16, 'earphone': 1, 'phone.': 5, 'worst': 9, 'salmon': 1, 'sashimi.': 1, "Doesn't": 3, 'hold': 3, 'charge.': 1, 'simple' ...
#
#
#
#
#
#
#
#
# {'So': 8, 'there': 12, 'is': 214, 'no': 8, 'way': 7, 'for': 68, 'me': 7, 'to': 135, 'plug': 1, 'it': 88, 'in': 88, 'here': 10, 'the': 357, 'US': 0, 'unless': 0, 'I': 193, 'go': 11, 'by': 15, 'a': 207, 'converter.': 0, 'A': 8, 'very,': 0, 'very': 73, 'slow-moving,': 0, 'aimless': 0, 'movie': 38, 'about': 15, 'distressed,': 0, 'drifting': 0, 'young': 2, 'man.': 0, 'Crust': 0, 'not': 22, 'good.': 9, 'Not': 3, 'sure': 2, 'who': 13, 'was': 136, 'more': 15, 'lost': 1, '-': 17, 'flat': 0, 'characters': 6, 'or': 11, 'audience,': 0, 'nearly': 2, 'half': 0, 'of': 136, 'whom': 0, 'walked': 1, 'out.': 5, 'tasty': 2, 'and': 315, 'texture': 1, 'just': 25, 'nasty.': 0, 'Attempting': 0, 'artiness': 0, 'with': 70, 'black': 3, '&': 7, 'white': 2, 'clever': 1, 'camera': 6, 'angles,': 0, 'disappointed': 0, 'became': 0, 'even': 9, 'ridiculous': 0, 'as': 39, 'acting': 3, 'poor': 0, 'plot': 0, 'lines': 0, 'almost': 2, 'non-existent.': 0, 'Tied': 0, 'charger': 2, 'conversations': 0, 'lasting': 0, 'than': 15, '45': 0, 'minutes.MAJOR': 0, 'PROBLEMS!!': 0, 'Very': 13, 'little': 9, 'music': 2, 'anything': 1, 'speak': 0, 'of.': 1, 'Now': 4, 'am': 8, 'getting': 1, 'angry': 0, 'want': 6, 'my': 50, 'damn': 0, 'pho.': 0, 'have': 43, 'jiggle': 0, 'get': 10, 'line': 2, 'up': 11, 'right': 8, 'decent': 3, 'volume.': 0, 'The': 106, 'rest': 0, 'lacks': 0, 'art,': 1, 'charm,': 0, 'meaning...': 0, 'If': 8, "it's": 15, 'emptiness,': 0, 'works': 19, 'guess': 0, 'because': 11, 'empty.': 0, 'Honeslty': 0, "didn't": 3, 'taste': 3, 'THAT': 0, 'fresh.)': 0, 'you': 27, 'several': 6, 'dozen': 1, 'hundred': 0, 'contacts,': 0, 'then': 1, 'imagine': 0, 'fun': 5, 'sending': 1, 'each': 4, 'them': 9, 'one': 34, 'one.': 1, 'Wasted': 0, 'two': 3, 'hours.': 0, 'potatoes': 0, 'were': 27, 'like': 31, 'rubber': 0, 'could': 10, 'tell': 2, 'they': 20, 'had': 35, 'been': 13, 'made': 14, 'ahead': 0, 'time': 14, 'being': 5, 'kept': 2, 'under': 2, 'warmer.': 0, 'Needless': 0, 'say,': 1, 'wasted': 1, 'money.': 0, 'bit': 1, 'predictable.': 0, 'What': 2, 'waste': 0, 'money': 2, 'time!.': 0, 'Would': 1, 'back.': 2, 'cashier': 0, 'care': 1, 'what': 11, 'so': 37, 'ever': 13, 'on': 46, 'say': 7, 'still': 6, 'ended': 0, 'wayyy': 0, 'overpriced.': 0, 'seperated': 0, 'mere': 0, '5+': 0, 'ft': 0, 'started': 0, 'notice': 1, 'excessive': 0, 'static': 0, 'garbled': 0, 'sound': 11, 'from': 16, 'headset.': 3, 'disgusted': 0, 'pretty': 9, 'that': 46, 'human': 0, 'hair.': 1, 'design': 1, 'odd,': 0, 'ear': 2, '"clip"': 0, 'comfortable': 6, 'at': 14, 'all.': 0, 'shocked': 0, 'signs': 0, 'indicate': 0, 'cash': 0, 'only.': 0, 'It': 35, 'some': 12, 'average': 0, 'main': 0, 'person,': 0, 'low': 1, 'budget': 0, 'clearly': 0, 'can': 11, 'see.': 1, 'advise': 1, 'EVERYONE': 1, 'DO': 0, 'NOT': 0, 'BE': 0, 'FOOLED!': 0, 'Waitress': 2, 'slow': 0, 'service.': 6, 'This': 59, 'place': 23, 'worth': 11, 'your': 11, 'time,': 2, 'let': 2, 'alone': 0, 'Vegas.': 5, 'did': 11, 'clicks': 0, 'into': 4, 'makes': 3, 'wonder': 0, 'how': 7, 'long': 5, 'mechanism': 0, 'would': 13, 'last.': 0, 'Burrittos': 0, 'Blah!': 0, 'went': 5, "Motorola's": 0, 'website': 1, 'followed': 0, 'all': 27, 'directions,': 0, 'but': 37, 'pair': 0, 'again.': 6, 'commercials': 0, 'are': 52, 'most': 13, 'misleading.': 0, 'bought': 2, 'mother': 1, 'she': 1, 'problem': 1, 'battery.': 1, 'short': 2, 'film': 27, 'certainly': 4, 'pulls': 0, 'punches.': 0, 'They': 7, 'never': 7, 'brought': 0, 'salad': 3, 'we': 13, 'asked': 0, 'for.': 0, 'Graphics': 0, 'far': 2, 'best': 22, 'part': 5, 'game.': 3, 'think': 15, 'instructions': 0, 'provided': 2, 'helpful': 2, 'me.': 4, 'Took': 0, 'an': 25, 'hour': 0, 'our': 13, 'food': 21, 'only': 9, '4': 0, 'tables': 0, 'restaurant': 7, 'Luke': 0, 'warm,': 0, 'Our': 2, 'sever': 0, 'running': 2, 'around': 1, 'he': 15, 'totally': 3, 'overwhelmed.': 0, 'People': 0, 'couldnt': 0, 'hear': 0, 'talk': 1, 'pull': 0, 'out': 15, 'earphone': 0, 'phone.': 10, 'worst': 1, 'salmon': 2, 'sashimi.': 0, "Doesn't": 0, 'hold': 0, 'charge.': 0, 'simple': 1, 'p ...

# %%
#this section counts the number of times a word in the class appears in the vocabulary and sums it up
sum_count0 = 0
sum_count1 = 0

for w in range(len(word_list0)):          #an iteration through the negative class bag of words
    count = 0
    check = word_list0[w]
    
    for k in range(lenV):          #an iteration through the vocabulary bag of words to check for the number of occurences for word
        if check == V[k]:
            count = count + 1
            
    sum_count0 = sum_count0 + count      #the summer adds the count up till all words in the class are exhausted
    

for w in range(len(word_list1)):          #same process applies for the positive class
    count = 0
    check = word_list1[w]
    
    for k in range(lenV):
        if check == V[k]:
            count = count + 1
            
    sum_count1 = sum_count1 + count
    
print(sum_count0)
print(sum_count1)
# Out:
# 988373
# 1016562

# %%
import math

def loglikelihood(word,class_type):
    
    if class_type == 0:
        count_val0 = count_word0[word]
        ans = math.log((count_val0 + 1)/(sum_count0 + lenV))
        
    else:
        count_val1 = count_word1[word]
        ans = math.log((count_val1 + 1)/(sum_count1 + lenV))
        
    return ans

# %%
def test_naive_bayes(testdoc):
    
    doc = open(testdoc,"r")
    result = open("results.txt","w")
    
    for line in doc:        
        doc_split = line.split()           
        print(doc_split)
    
        prob0 = 1
        for i in range(len(doc_split)):           
            res0 = loglikelihood(doc_split[i],0)     #finding the loglikelihood of each of the words
            prob0 = prob0 * res0                   #accumulating loglikelihood of words
        
        prob1 = 1
        for i in range(len(doc_split)):
            res1 = loglikelihood(doc_split[i],1)
            prob1 = prob1 * res1
       
        final_prob0 = prob0 * logprior['0']         #finding the probability of negative class
        print(final_prob0)
        final_prob1 = prob1 * logprior['1']         #finding the probablity of positive class
        print(final_prob1)
     
    
        if final_prob0 > final_prob1:           #comparing to see which class is greater
            result.write('0\n')
            
        else:
            result.write('1\n')
            
    return

# %%
test_naive_bayes('test.txt')
# Out:
# ['predictable', 'with', 'no', 'fun']
# -12127.691752136578
# -11745.126217670835
# ['this', 'is', 'a', 'good', 'one']
# 56711.755205977235
# 43469.53974071173
# ['i', 'think', "it's", 'cool']
# -15889.642430163132
# -11232.479397335983
# ['I', "didn't", 'enjoy', 'it', 'so', 'much']
# -839115.3295591502
# -1076716.3482545624

# %%
amazon.close()
yelp.close()
imdb.close()
